# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Define the file path
file_path = "/content/drive/MyDrive/8th_SEM_MP_2/DDI_types.xlsx"

# Load the Excel file
xls = pd.ExcelFile(file_path)

# Display sheet names
xls.sheet_names
# Out:
# ['Sheet1']

# %%
# Load the data from the first sheet
df = pd.read_excel(xls, sheet_name="Sheet1")

# Display basic information about the dataframe
df.info(), df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order                  114 non-null    int64
#  1   Origin DDI's type      114 non-null    object
#  2   merged DDI type index  114 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 2.8+ KB
# (None,
#     Order                        Origin DDI's type  merged DDI type index
#  0      1                            'metabolism',                      8
#  1      2                   'serum concentration',                      2
#  2      3          'risk or severity of bleeding',                      7
#  3      4              'anticoagulant activities',                     20
#  4      5   'risk or severity of adverse effects',                      7)

# %%
df
# Out:
#      Order                                  Origin DDI's type  \
# 0        1                                      'metabolism',
# 1        2                             'serum concentration',
# 2        3                    'risk or severity of bleeding',
# 3        4                        'anticoagulant activities',
# 4        5             'risk or severity of adverse effects',
# ..     ...                                                ...
# 109    110   'central nervous system depressant (CNS depre...
# 110    111        'risk or severity of intraocular pressure',
# 111    112                  'serum concentration of sulfate',
# 112    113         'risk or severity of generalized seizure',
# 113    114                     'risk or severity of sedation'
#
#      merged DDI type index
# 0                        8
# 1                        2
# 2                        7
# 3                       20
# 4                        7
# ..                     ...
# ...

# %%
del df["Order"]
df
# Out:
#                                      Origin DDI's type  merged DDI type index
# 0                                        'metabolism',                      8
# 1                               'serum concentration',                      2
# 2                      'risk or severity of bleeding',                      7
# 3                          'anticoagulant activities',                     20
# 4               'risk or severity of adverse effects',                      7
# ..                                                 ...                    ...
# 109   'central nervous system depressant (CNS depre...                     11
# 110        'risk or severity of intraocular pressure',                      7
# 111                  'serum concentration of sulfate',                      2
# 112         'risk or severity of generalized seizure',                      7
# 113                     'risk or severity of sedation'                     19
#
# [114 rows x 2 columns]

# %%
df.head()
# Out:
#                          Origin DDI's type  merged DDI type index
# 0                            'metabolism',                      8
# 1                   'serum concentration',                      2
# 2          'risk or severity of bleeding',                      7
# 3              'anticoagulant activities',                     20
# 4   'risk or severity of adverse effects',                      7

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
file_path = "/content/drive/MyDrive/8th_SEM_MP_2/DDI_types.xlsx"
df = pd.read_excel(file_path, sheet_name="Sheet1")

# Set figure size
plt.figure(figsize=(12, 6))

# Create a bar plot
sns.countplot(data=df, x="merged DDI type index", palette="viridis")

# Add labels and title
plt.xlabel("Merged DDI Type Index")
plt.ylabel("Count")
plt.title("Distribution of Merged DDI Type Indices")

# Show the plot
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-8-45415b492567>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="merged DDI type index", palette="viridis")

# %%
# Count the occurrences of each DDI type
ddi_counts = df["merged DDI type index"].value_counts()

# Plot a pie chart
plt.figure(figsize=(10, 8))
ddi_counts.plot.pie(autopct="%1.1f%%", cmap="Set3", startangle=90)

# Add title
plt.title("Proportion of Origin DDI Types")

# Show the plot
plt.ylabel("")  # Remove y-label
plt.show()

# %%
from wordcloud import WordCloud

# Combine all text from the "Origin DDI's type" column
text = " ".join(df["Origin DDI's type"].astype(str))

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

# Display the word cloud
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud of DDI Types")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(y=df["merged DDI type index"], color="lightblue")

plt.title("Box Plot of Merged DDI Type Indices")
plt.ylabel("Merged DDI Type Index")
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df["merged DDI type index"], bins=20, kde=True, color="green")

plt.title("Histogram of Merged DDI Type Indices")
plt.xlabel("Merged DDI Type Index")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# Violin Plot: Distribution of Merged DDI Type Indices
# Violin plots show data distribution with density estimation.

# %%
plt.figure(figsize=(8, 5))
sns.violinplot(y=df["merged DDI type index"], color="purple")

plt.title("Violin Plot of Merged DDI Type Indices")
plt.ylabel("Merged DDI Type Index")
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np # Import numpy for array operations

# Sample data (replace with your actual data)
categories = ['Category 1', 'Category 2', 'Category 3', 'Category 4', 'Category 5']
values = [4, 6, 2, 8, 5]

# Number of variables
num_vars = len(categories)

# Angle for each axis
angles = [n / float(num_vars) * 2 * 3.14159 for n in range(num_vars)]
angles += angles[:1]

# Initialize the spider plot
ax = plt.subplot(111, polar=True)

# Plot the data
ax.plot(angles, values + values[:1], 'o-', linewidth=2)

# Fill the area
ax.fill(angles, values + values[:1], alpha=0.25)

# Set the labels for each axis
# Convert angles[:-1] to a NumPy array for element-wise operations
ax.set_thetagrids(np.array(angles[:-1]) * 180/3.14159, categories)

# Set the limits for the radial axis
plt.ylim(0, max(values) * 1.2) # Adjust the limit as needed

# Add a title
plt.title("Spider Plot")

# Display the plot
plt.show()
